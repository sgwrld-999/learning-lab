# %% [markdown]
# ### UPSC Essay Evaluation Assistant
#
# #### Nodes
# The assistant is composed of three main nodes:
# 1.  **Analysis Node**: Analyzes the essay and provides overall feedback.
# 2.  **Evaluate LANGUAGE Node**: Evaluates the language quality of the essay.
# 3.  **Evaluate Thought Process Node**: Evaluates the thought process and content quality of the essay.
# 4. **Summary Node**: Merges the outputs from the evaluation nodes and provides a consolidated feedback report.
#
# #### Topics for Practice
# The following concepts will be used in this example:
# -   **Reducers**: Merge multiple outputs into a single value. Without a reducer, subsequent outputs would replace previous ones.
# -   **Structured Output**: Ensuring the output from the models conforms to a specific schema.
# -   **Parallel Workflows**: Executing multiple tasks concurrently and returning partial results as they become available.

# %%
# !pip install langgraph langchain_google_genai
# standards imports 
import os
from typing import TypedDict, Annotated
from dotenv import load_dotenv
import operator

# third-party imports
from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
# Out:
# Requirement already satisfied: langgraph in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (1.0.3)
# Requirement already satisfied: langchain_google_genai in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (3.1.0)
# Requirement already satisfied: langchain-core>=0.1 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langgraph) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langgraph) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langgraph) (0.2.9)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langgraph) (2.12.0)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langchain_google_genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<1.0.0,>=0.9.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langchain_google_genai) (0.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (2.41.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (1.75.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (5.29.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langchain-core>=0.1->langgraph) (0.4.46)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from pydantic>=2.7.4->langgraph) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (2.32.5)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (1.71.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (4.9.1)
# Requirement already satisfied: anyio in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (4.11.0)
# Requirement already satisfied: certifi in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/siddhantgond/Desktop/Github_Modules/google_adk_kit/vir_env/lib/python3.13/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.3.1)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
load_dotenv()
# Out:
# True

# %%
gemini_model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)
# Out:
# E0000 00:00:1763883007.073222  314191 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.

# %%
# structured output class
# this is for the model which means how the model will return the output
class EvaluationSchema(BaseModel):
    
    feedback : str = Field(description="Detrailed Feedback for the essay")
    score    : int = Field(description="Score out of 10", ge=0, le=10)
    
structured_model = gemini_model.with_structured_output(EvaluationSchema)

# %%
# this is for the langgraph or graph components not for the model
class UPSCState(TypedDict):
    essay : str
    language_feedback : str
    analysis_feedback : str
    thought_feedback : str
    overall_feedback : str
    individual_score : Annotated[list[int], operator.add]
    avg_score : float

# %%
# Define evaluation prompts for each evaluation dimension
# Each prompt instructs the model to act as an expert UPSC evaluator

# Language evaluation: Focuses on grammar, vocabulary, syntax, and clarity
language_prompt = """You are an expert Union Public Service Commission (UPSC) Essay evaluator invigilator. 
You have over 10+ Years of Experience (YOE). Your task is to evaluate the following essay on the basis of 
language quality including grammar, vocabulary, sentence structure, clarity, and coherence. 
Rate the essay on a scale of 10.

Essay: {essay}
"""

# Thought process evaluation: Focuses on logical flow, critical thinking, and argumentation
thought_prompt = """You are an expert Union Public Service Commission (UPSC) Essay evaluator invigilator. 
You have over 10+ Years of Experience (YOE). Your task is to evaluate the following essay on the basis of 
thought process, including logical reasoning, critical thinking, depth of analysis, and coherence of arguments. 
Rate the essay on a scale of 10.

Essay: {essay}
"""

# Analysis evaluation: Focuses on content quality, examples, and insights
analysis_prompt = """You are an expert Union Public Service Commission (UPSC) Essay evaluator invigilator. 
You have over 10+ Years of Experience (YOE). Your task is to evaluate the following essay on the basis of 
analytical depth, quality of examples, real-world applications, and insightful observations. 
Rate the essay on a scale of 10.

Essay: {essay}
"""


def language_evaluation(state: UPSCState):
    """
    Evaluates the language quality of the essay.
    
    Args:
        state (UPSCState): Current state containing the essay
        
    Returns:
        dict: Updated state with language feedback and score
    """
    # Format the prompt with the essay text
    prompt = language_prompt.format(essay=state["essay"])
    
    # Invoke the structured model to get evaluation
    output = structured_model.invoke(prompt)
    
    # Return the feedback and append score to individual_score list
    return {
        "language_feedback": output.feedback,
        "individual_score": [output.score]
    }


def thought_evaluation(state: UPSCState):
    """
    Evaluates the thought process and logical reasoning in the essay.
    
    Args:
        state (UPSCState): Current state containing the essay
        
    Returns:
        dict: Updated state with thought process feedback and score
    """
    # Format the prompt with the essay text
    prompt = thought_prompt.format(essay=state["essay"])
    
    # Invoke the structured model to get evaluation
    output = structured_model.invoke(prompt)
    
    # Return the feedback and append score to individual_score list
    return {
        "thought_feedback": output.feedback,
        "individual_score": [output.score]
    }


def analysis_evaluation(state: UPSCState):
    """
    Evaluates the analytical depth and quality of content in the essay.
    
    Args:
        state (UPSCState): Current state containing the essay
        
    Returns:
        dict: Updated state with analysis feedback and score
    """
    # Format the prompt with the essay text
    prompt = analysis_prompt.format(essay=state["essay"])
    
    # Invoke the structured model to get evaluation
    output = structured_model.invoke(prompt)
    
    # Return the feedback and append score to individual_score list
    return {
        "analysis_feedback": output.feedback,
        "individual_score": [output.score]
    }


def final_evaluation(state: UPSCState):
    """
    Consolidates all individual evaluations and computes the average score.
    
    Args:
        state (UPSCState): Current state with all feedback and scores
        
    Returns:
        dict: Updated state with overall feedback and average score
    """
    # Calculate average score from all individual scores
    avg_score = sum(state["individual_score"]) / len(state["individual_score"])
    
    # Compile overall feedback by combining all individual feedback
    overall_feedback = f"""
=== UPSC ESSAY EVALUATION REPORT ===

LANGUAGE EVALUATION:
{state['language_feedback']}

THOUGHT PROCESS EVALUATION:
{state['thought_feedback']}

ANALYTICAL EVALUATION:
{state['analysis_feedback']}

FINAL AVERAGE SCORE: {avg_score:.2f}/10
"""
    
    # Return the consolidated results
    return {
        "overall_feedback": overall_feedback,
        "avg_score": avg_score
    }

# %%
# Create the StateGraph with UPSCState as the state schema
graph = StateGraph(UPSCState)


# Add nodes to the graph
# Each node is identified by a string name and associated with its function
graph.add_node('thought_evaluation', thought_evaluation)
graph.add_node('analysis_evaluation', analysis_evaluation)
graph.add_node('language_evaluation', language_evaluation)
graph.add_node('final_evaluation', final_evaluation)

# Define the graph structure with edges
# Level 0: START node branches to three parallel evaluation nodes
# Level 1: Three evaluation nodes run in parallel
graph.add_edge(START, 'language_evaluation')
graph.add_edge(START, 'analysis_evaluation')
graph.add_edge(START, 'thought_evaluation')

# Level 2: All three evaluations converge to final_evaluation node
graph.add_edge('language_evaluation', 'final_evaluation')
graph.add_edge('analysis_evaluation', 'final_evaluation')
graph.add_edge('thought_evaluation', 'final_evaluation')

# Level 3: Final evaluation connects to END
graph.add_edge('final_evaluation', END)

# Compile the graph to create the runnable workflow
compiled_graph = graph.compile()

# %%
compiled_graph

# %%
essay1 = """India and AI Time

Now world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.

India have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.

In farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.

But problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.

One more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.

India must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.

If India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.

So, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India"."""

# %%
initial_state = {
    'essay' : essay1
}

compiled_graph.invoke(initial_state)
# Out:
# {'essay': 'India and AI Time\n\nNow world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.\n\nIndia have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.\n\nIn farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.\n\nBut problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.\n\nOne more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.\n\nIndia must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.\n\nIf India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.\n\nSo, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India".',
#  'language_feedback': "The essay demonstrates significant deficiencies in language quality, which would be highly detrimental in a UPSC examination. There are pervasive grammatical errors, including issues with subject-verb agreement, tenses, article usage, and sentence construction. The vocabulary is extremely limited, informal, and includes misspellings ('engine-ear', 'peoples'). Sentence structures are overly simplistic and repetitive, lacking the complexity and sophistication expected from a civil service aspirant. While the essay attempts to cover relevant points regarding AI in India, the clarity of expression is severely hampered by these linguistic shortcomings. Coherence is present at a very basic level, but the lack of proper transitions and complex sentences makes the essay read disjointedly. Overall, the essay requires extensive improvement in fundamental English language skills to meet the standards of a competitive examination like UPSC.",
#  'analysis_feedback': "As an expert UPSC Essay evaluator, I must point out that this essay falls significantly short of the expected standards for a competitive examination like the UPSC. \n\n**1. Analytical Depth:** The essay offers a very superficial understanding of the topic. While it identifies some potential benefits of AI in India (agriculture, health, education, governance) and challenges (digital divide, job displacement, privacy), it fails to delve into any of these points with meaningful analysis. There is no exploration of the 'how' or 'why', no discussion of policy implications, ethical frameworks, or the complex socio-economic impact beyond surface-level statements. For instance, the discussion on job loss or privacy is extremely rudimentary.\n\n**2. Quality of Examples:** The examples provided are generic at best (TCS, Infosys, Wipro, 'AI for All' program, general sectors). There is a complete absence of specific, detailed, or impactful examples that would demonstrate a deep understanding of AI's real-world applications or challenges in India. These are more categories than concrete examples.\n\n**3. Real-world Applications:** While the essay lists relevant areas where AI can be applied (farm, doctor, school), the description of these applications is extremely basic and lacks any practical or technical detail. It merely states potential uses without elaborating on their implementation or impact.\n\n**4. Insightful Observations:** The observations made are largely common knowledge and lack any profound, original, or critical insight expected from a UPSC candidate. Statements like 'AI must help all people, not only some' are basic moral points rather than insightful observations within a complex policy and technological discourse.\n\n**5. Language and Structure:** This is a major area of concern. The language is extremely simplistic, informal, and indicative of a very limited command of English, far below the standard required for a UPSC essay. The grammatical errors, elementary vocabulary, and fragmented sentences hinder comprehension and reflect poorly on the candidate's communication skills. The essay also lacks a coherent structure, with disjointed paragraphs and no clear introduction, body, or conclusion.\n\n**Overall:** The essay demonstrates a very rudimentary understanding of both the topic of AI in India and the art of essay writing for a competitive examination. It lacks the sophistication, depth, clarity, and analytical rigor expected. For a UPSC essay, it would be considered extremely weak.",
#  'thought_feedback': "This essay demonstrates a rudimentary understanding of the topic 'India and AI Time' but falls significantly short of the expected standards for a UPSC essay.\n\n**Thought Process:**\n*   **Logical Reasoning:** The essay follows a basic, predictable structure of identifying opportunities, challenges, and solutions. However, the reasoning within each point is extremely simplistic and lacks depth. Arguments are presented as mere statements rather than developed lines of thought (e.g., 'AI help farmer know when to put seed' without further elaboration).\n*   **Critical Thinking:** There is a notable absence of critical thinking. The essay merely lists points without delving into the complexities, nuances, trade-offs, or potential counter-arguments. For instance, the 'AI for All' program is mentioned positively without any critical examination of its implementation hurdles or specific successes/failures. Challenges like job displacement and privacy are identified but not analyzed with the required depth or policy implications.\n*   **Depth of Analysis:** The analysis is very superficial. Each point is touched upon briefly without any supporting evidence, examples, or detailed exploration of its socio-economic, ethical, or governance implications. The essay reads more like a bullet-point summary rather than a developed analytical piece.\n\n**Coherence of Arguments:**\n*   While the essay broadly follows an introduction-body-conclusion format, the arguments themselves are not well-developed or seamlessly connected. The transitions between ideas within and across paragraphs are often abrupt, making the overall flow feel disjointed. The simplistic language further hinders the establishment of complex relationships between ideas.\n\n**Language and Expression:**\n*   This is a major area of concern. The language used is extremely basic, informal, and contains numerous grammatical errors, spelling mistakes ('engine-ear,' 'doctor place,' 'Intel... something,' 'big big data'), and colloquialisms ('no careful,' 'no get,' 'good job India'). Such rudimentary expression severely undermines the essay's credibility and makes it impossible to convey sophisticated thoughts or nuanced arguments, which are paramount in a UPSC examination. The lack of varied vocabulary and complex sentence structures restricts the ability to articulate any deep analysis.\n\n**Overall:**\nThe essay needs substantial improvement across all parameters. To meet UPSC standards, the candidate must focus on developing a much deeper analytical perspective, engaging in critical thinking, supporting arguments with specific details and examples, and significantly enhancing their command over language, grammar, and formal expression.",
#  'overall_feedback': "\n=== UPSC ESSAY EVALUATION REPORT ===\n\nLANGUAGE EVALUATION:\nThe essay demonstrates significant deficiencies in language quality, which would be highly detrimental in a UPSC examination. There are pervasive grammatical errors, including issues with subject-verb agreement, tenses, article usage, and sentence construction. The vocabulary is extremely limited, informal, and includes misspellings ('engine-ear', 'peoples'). Sentence structures are overly simplistic and repetitive, lacking the complexity and sophistication expected from a civil service aspirant. While the essay attempts to cover relevant points regarding AI in India, the clarity of expression is severely hampered by these linguistic shortcomings. Coherence is present at a very basic level, but the lack of proper transitions and complex sentences makes the essay read disjointedly. Overall, the essay requires extensive improvement in fundamental English language skills to meet the standards of a competitive examination like UPSC.\n\nTHOUGHT PROCESS EVALUATION:\nThis essay demonstrates a rudimentary understanding of the topic 'India and AI Time' but falls significantly short of the expected standards for a UPSC essay.\n\n**Thought Process:**\n*   **Logical Reasoning:** The essay follows a basic, predictable structure of identifying opportunities, challenges, and solutions. However, the reasoning within each point is extremely simplistic and lacks depth. Arguments are presented as mere statements rather than developed lines of thought (e.g., 'AI help farmer know when to put seed' without further elaboration).\n*   **Critical Thinking:** There is a notable absence of critical thinking. The essay merely lists points without delving into the complexities, nuances, trade-offs, or potential counter-arguments. For instance, the 'AI for All' program is mentioned positively without any critical examination of its implementation hurdles or specific successes/failures. Challenges like job displacement and privacy are identified but not analyzed with the required depth or policy implications.\n*   **Depth of Analysis:** The analysis is very superficial. Each point is touched upon briefly without any supporting evidence, examples, or detailed exploration of its socio-economic, ethical, or governance implications. The essay reads more like a bullet-point summary rather than a developed analytical piece.\n\n**Coherence of Arguments:**\n*   While the essay broadly follows an introduction-body-conclusion format, the arguments themselves are not well-developed or seamlessly connected. The transitions between ideas within and across paragraphs are often abrupt, making the overall flow feel disjointed. The simplistic language further hinders the establishment of complex relationships between ideas.\n\n**Language and Expression:**\n*   This is a major area of concern. The language used is extremely basic, informal, and contains numerous grammatical errors, spelling mistakes ('engine-ear,' 'doctor place,' 'Intel... something,' 'big big data'), and colloquialisms ('no careful,' 'no get,' 'good job India'). Such rudimentary expression severely undermines the essay's credibility and makes it impossible to convey sophisticated thoughts or nuanced arguments, which are paramount in a UPSC examination. The lack of varied vocabulary and complex sentence structures restricts the ability to articulate any deep analysis.\n\n**Overall:**\nThe essay needs substantial improvement across all parameters. To meet UPSC standards, the candidate must focus on developing a much deeper analytical perspective, engaging in critical thinking, supporting arguments with specific details and examples, and significantly enhancing their command over language, grammar, and formal expression.\n\nANALYTICAL EVALUATION:\nAs an expert UPSC Essay evaluator, I must point out that this essay falls significantly short of the expected standards for a competitive examination like the UPSC. \n\n**1. Analyti ...
#  'individual_score': [2, 2, 2],
#  'avg_score': 2.0}
