# %%
# !pip install fastapi
# Out:
# Requirement already satisfied: fastapi in /Users/siddhantgond/miniconda3/lib/python3.13/site-packages (0.116.1)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /Users/siddhantgond/miniconda3/lib/python3.13/site-packages (from fastapi) (0.47.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /Users/siddhantgond/miniconda3/lib/python3.13/site-packages (from fastapi) (2.10.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/siddhantgond/miniconda3/lib/python3.13/site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/siddhantgond/miniconda3/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Users/siddhantgond/miniconda3/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.27.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/siddhantgond/miniconda3/lib/python3.13/site-packages (from starlette<0.48.0,>=0.40.0->fastapi) (4.7.0)
# Requirement already satisfied: idna>=2.8 in /Users/siddhantgond/miniconda3/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /Users/siddhantgond/miniconda3/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.0)

# %%
# !pip list | grep fastapi
# Out:
# fastapi                                  0.116.1

# %%
from fastapi import FastAPI

app = FastAPI()

# %%
@app.get("check1")
def check1():
    return {message: "you call check1 hit point"}

# %%
@app.get("check2")
def check1():
    return {message: "you call check2 hit point"}

# %%
# !univorn
# Out:
# zsh:1: command not found: univorn
